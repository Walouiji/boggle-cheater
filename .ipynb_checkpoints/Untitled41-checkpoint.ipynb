# %%
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt
from numpy import asarray

stored_tuple = []

# %%
img = Image.open('A.png')
numpydata = asarray(img)
numpydata
stored_tuple.append((numpydata, "A"))

img = Image.open('A1.png')
numpydata = asarray(img)
numpydata
stored_tuple.append((numpydata, "A"))

img = Image.open('B.png')
numpydata = asarray(img)
numpydata
stored_tuple.append((numpydata, "B"))

img = Image.open('B1.png')
numpydata = asarray(img)
numpydata
stored_tuple.append((numpydata, "B1"))

# %%
stored_tuple

# %%
stored_tuple[0][0]

# %%
plt.imshow(stored_tuple[0][0])
